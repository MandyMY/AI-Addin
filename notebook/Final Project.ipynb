# %%
import h2o
import operator
from h2o.automl import H2OAutoML
import random, os, sys
from datetime import datetime
import pandas as pd
import logging
import csv
import optparse
import time
import json
from distutils.util import strtobool
import psutil
import numpy as np
from matplotlib import pyplot as plt
import warnings
import sys
sys.path.append('../plot/')
from ice import ice, ice_plot
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
from h2o.estimators import H2OGradientBoostingEstimator
warnings.filterwarnings("ignore")
from h2o.estimators.random_forest import H2ORandomForestEstimator
from IPython.display import Image, display
from h2o.backend import H2OLocalServer
import subprocess
# %matplotlib inline

# %% [markdown]
# # 1 Data Preparation

# %% [markdown]
# ## 1.1 H2O Initialization

# %%
pct_memory=4
virtual_memory=psutil.virtual_memory()
min_mem_size=int(round(int(pct_memory*virtual_memory.available)/1073741824,0))
print(min_mem_size)
# Out:
# 19

# %%
h2o.init(strict_version_check=False,max_mem_size=min_mem_size)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ---------------------------------------------------
# H2O cluster uptime:         8 hours 0 mins
# H2O cluster timezone:       America/New_York
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.24.0.2
# H2O cluster version age:    9 days
# H2O cluster name:           H2O_from_python_mandy_jpex0n
# H2O cluster total nodes:    1
# H2O cluster free memory:    26.92 Gb
# H2O cluster total cores:    12
# H2O cluster allowed cores:  12
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             3.7.2 final
# --------------------------  ---------------------------------------------------

# %% [markdown]
# ## 1.2 Data Import & Parse

# %%
data_path = "../data/AmazonReviews.Small.csv"

# Load data into H2O
reviews = h2o.import_file(data_path)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
reviews.shape
# Out:
# (55554, 10)

# %%
reviews.head(3)
# Out:
# <table>
# <thead>
# <tr><th>ProductId  </th><th>UserId        </th><th>Summary                     </th><th style="text-align: right;">  Score</th><th style="text-align: right;">  HelpfulnessDenominator</th><th style="text-align: right;">    Id</th><th>ProfileName        </th><th style="text-align: right;">  HelpfulnessNumerator</th><th style="text-align: right;">       Time</th><th>Text                                                                                                                                                                                                                                                                                                                                                                            </th></tr>
# </thead>
# <tbody>
# <tr><td>B00141QYSQ </td><td>A1YS02UZZGRDCT</td><td>Do Not Buy                  </td><td style="text-align: right;">      1</td><td style="text-align: right;">                       2</td><td style="text-align: right;"> 41471</td><td>Evan Eberhardt     </td><td style="text-align: right;">                     2</td><td style="text-align: right;">1.34836e+09</td><td>These are made in China (do not buy ANY pet food from China).  Dogswell has been using propylene glycol to soften their treats (what are they thinkng?).  Do not purchase or support this company in any way until they clean up their act.  And for whatever reason Amazon doesn't allow returns of this item, so I had to toss mine out.  Bad business all around on this one.</td></tr>
# <tr><td>B0089SPEO2 </td><td>A3JOYNYL458QHP</td><td>Less lemon and less zing    </td><td style="text-align: right;">      3</td><td style="text-align: right;">                       0</td><td style="text-align: right;"> 28582</td><td>coleridge          </td><td style="text-align: right;">                     0</td><td style="text-align: right;">1.32391e+09</td><td>Everything is ok, except it just isn't as good as it is in the bags.  Just considerably more bland -- less lemon and less zing.  Boring.                                                                                                                                                                                                                                        </td></tr>
# <tr><td>B001PMCDK2 </td><td>A14TTMM0Z03Y2W</td><td>my cat goes crazy for these!</td><td style="text-align: right;">      5</td><td style="text-align: right;">                       0</td><td style="text-align: right;">389965</td><td>Lindsay S. Bradford</td><td style="text-align: right;">                     0</td><td style="text-align: right;">1.3106e+09 </td><td>Best cat treat ever. There isn't anything comparable to the love my cat has for these treats, he snubs away any other kind now.<br />I know he likes to manipulate me with his cattiness but these treats are my way of manipulating him to come sit on my lap and have some chill time. :)                                                                                     </td></tr>
# </tbody>
# </table>

# %%
reviews['PositiveReview']=(reviews['Score']>=reviews['Score'].mean()[0]).ifelse('1','0')

# %%
reviews['PositiveReview'].table()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  PositiveReview</th><th style="text-align: right;">  Count</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">               0</td><td style="text-align: right;">  20106</td></tr>
# <tr><td style="text-align: right;">               1</td><td style="text-align: right;">  35448</td></tr>
# </tbody>
# </table>

# %%
# Find the 80th quantile of time in the dataset
time_split = reviews["Time"].quantile(prob = [0.8])[1]
reviews["Train"] = (reviews["Time"] < time_split).ifelse("Yes", "No")

# %%
reviews['Train'].table()
# Out:
# <table>
# <thead>
# <tr><th>Train  </th><th style="text-align: right;">  Count</th></tr>
# </thead>
# <tbody>
# <tr><td>No     </td><td style="text-align: right;">  11152</td></tr>
# <tr><td>Yes    </td><td style="text-align: right;">  44402</td></tr>
# </tbody>
# </table>

# %%
train = reviews[reviews["Train"] == "Yes"]
test = reviews[reviews["Train"] == "No"]

# %% [markdown]
# ## 1.3 Tokenize Words in Review

# %%
data_path = "../data/stopwords.csv"
STOP_WORDS = pd.read_csv(data_path, header=0)

# %%
STOP_WORDS.head()
# Out:
#   STOP_WORD
# 0       all
# 1      just
# 2     being
# 3      over
# 4      both

# %%
STOP_WORDS = list(STOP_WORDS['STOP_WORD'])

# %%
def tokenize(sentences, stop_word = STOP_WORDS):
    tokenized = sentences.tokenize("\\W+")
    tokenized_lower = tokenized.tolower()
    tokenized_filtered = tokenized_lower[(tokenized_lower.nchar() >= 2) | (tokenized_lower.isna()),:]
    tokenized_words = tokenized_filtered[tokenized_filtered.grep("[0-9]",invert=True,output_logical=True),:]
    tokenized_words = tokenized_words[(tokenized_words.isna()) | (~ tokenized_words.isin(STOP_WORDS)),:]
    return tokenized_words

# %%
# Break reviews into sequence of words
words = tokenize(reviews["Text"])

# %%
words.head()
# Out:
# <table>
# <thead>
# <tr><th>C1       </th></tr>
# </thead>
# <tbody>
# <tr><td>made     </td></tr>
# <tr><td>china    </td></tr>
# <tr><td>buy      </td></tr>
# <tr><td>pet      </td></tr>
# <tr><td>food     </td></tr>
# <tr><td>china    </td></tr>
# <tr><td>dogswell </td></tr>
# <tr><td>using    </td></tr>
# <tr><td>propylene</td></tr>
# <tr><td>glycol   </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## 1.4 Word2Vec Model

# %%
# Train Word2Vec Model
from h2o.estimators.word2vec import H2OWord2vecEstimator

w2v_model = H2OWord2vecEstimator(vec_size = 100, model_id = "w2v_amazon.hex")
w2v_model.train(training_frame=words)

models_path='../data'
h2o.save_model(w2v_model, path = models_path, force = True)
# Out:
# word2vec Model Build progress: |██████████████████████████████████████████| 100%
# '/Users/mandy/Desktop/AI-Addin/data/w2v_amazon.hex'

# %%
# Sanity check - find synonyms for the word 'coffee'
w2v_model.find_synonyms("coffee", count = 5)
# Out:
# OrderedDict([('coffees', 0.8129487037658691),
#              ('coffe', 0.7903681993484497),
#              ('expresso', 0.7478470206260681),
#              ('espresso', 0.7478417158126831),
#              ('java', 0.7437924742698669)])

# %%
# Sanity check - find synonyms for the word 'stale'
w2v_model.find_synonyms("stale", count = 5)
# Out:
# OrderedDict([('rancid', 0.6636177897453308),
#              ('unedible', 0.6335509419441223),
#              ('expired', 0.6334084868431091),
#              ('tasteless', 0.6016961336135864),
#              ('inedible', 0.5982323884963989)])

# %%
# Calculate a vector for each review
review_vecs = w2v_model.transform(words, aggregate_method = "AVERAGE")
review_vecs
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;
text-align: right;"> 0.179411 </td><td style="text-align: right;">0.0793897 </td><td style="text-align: right;"> 0.0795455 </td><td style="text-align: right;">0.07032  </td><td style="text-align: right;">-0.122812 </td><td style="text-align: right;">0.0253186 </td><td style="text-align: right;">-0.0340837</td><td style="text-align: right;">-0.0734328</td><td style="text-align: right;">0.0487423</td><td style="text-align: right;">0.158422</td><td style="text-align: right;">-0.054956 </td><td style="text-align: right;">0.0687226</td><td style="text-align: right;"> 0.0875092</td><td style="text-align: right;">0.0217279</td><td style="text-align: right;">-0.00629102</td><td style="text-align: right;"> 0.108607 </td><td style="text-align: right;">-0.0208836</td><td style="text-align: right;"> 0.00463367</td><td style="text-align: right;">0.0332915</td><td style="text-align: right;">0.182669</td><td style="text-align: right;">0.0727023 </td><td style="text-align: right;"> 0.0616679</td><td style="text-align: right;">-0.115229 </td><td style="text-align: right;">0.116817</td><td style="text-align: right;"> 0.0596724</td><td style="text-align: right;">

# %% [markdown]
# ## 1.5 Add Summary Column

# %%
# Break summaries into sequence of word.
summary_words = tokenize(reviews['Summary'].ascharacter())

# %%
summary_vecs = w2v_model.transform(summary_words, aggregate_method='AVERAGE')
summary_vecs.names = ['summary_'+ s for s in summary_vecs.names]

ext_reviews_new = ext_reviews.cbind(summary_vecs)

# %%
ext_reviews_new.head(3)
# Out:
# <table>
# <thead>
# <tr><th>ProductId  </th><th>UserId        </th><th>Summary                     </th><th style="text-align: right;">  Score</th><th style="text-align: right;">  HelpfulnessDenominator</th><th style="text-align: right;">    Id</th><th>ProfileName        </th><th style="text-align: right;">  HelpfulnessNumerator</th><th style="text-align: right;">       Time</th><th>Text                                                                                                                                                                                                                                                                                                                                                                            </th><th style="text-align: right;">  PositiveReview</th><th>Train  </th><th style="text-align: right;">        C1</th><th style="text-align: right;">        C2</th><th style="text-align: right;">        C3</th><th style="text-align: right;">        C4</th><th style="text-align: right;">      C5</th><th style="text-align: right;">         C6</th><th style="text-align: right;">       C7</th><th style="text-align: right;">       C8</th><th style="text-align: right;">      C9</th><th style="text-align: right;">        C10</th><th style="text-align: right;">       C11</th><th style="text-align: right;">       C12</th><th style="text-align: right;">      C13</th><th style="text-align: right;">       C14</th><th style="text-align: right;">       C15</th><th style="text-align: right;">        C16</th><th style="text-align: right;">      C17</th><th style="text-align: right;">       C18</th><th style="text-align: right;">       C19</th><th style="text-align: right;">       C20</th><th style="text-align: right;">       C21</th><th style="text-align: right;">      C22</th><th style="text-align: right;">     C23</th><th style="text-align: right;">       C24</th><th style="text-align: right;">      C25</th><th style="text-align: right;">       C26</th><th style="text-align: right;">      C27</th><th style="text-align: right;">        C28</th><th style="text-align: right;">       C29</th><th style="text-align: right;">       C30</th><th style="text-align: right;">        C31</th><th style="text-align: right;">      C32</th><th style="text-align: right;">     C33</th><th style="text-align: right;">       C34</th><th style="text-align: right;">       C35</th><th style="text-align: right;">       C36</th><th style="text-align: right;">     C37</th><th style="text-align: right;">       C38</th><th style="text-align: right;">        C39</th><th style="text-align: right;">       C40</th><th style="text-align: right;">       C41</th><th style="text-align: right;">         C42</th><th style="text-align: right;">      C43</th><th style="text-align: right;">       C44</th><th style="text-align: right;">        C45</th><th style="text-align: right;">       C46</th><th style="text-align: right;">       C47</th><th style="text-align: right;">       C48</th><th style="text-align: right;">       C49</th><th style="text-align: right;">        C50</th><th style="text-align: right;">        C51</th><th style="text-align: right;">       C52</th><th style="text-align: right;">       C53</th><th style="text-align: right;">      C54</th><th style="text-align: right;">       C55</th><th style="text-align: right;">       C56</th><th style="text-align: right;">       C57</th><th style="text-align: right;">       C58</th><th style="text-align: right;">      C59</th><th style="text-align: right;">       C60</th><th style="text-align: right;">      C61</th><th style="text-align: right;">        C62</th><th style="text-align: right;">      C63</th><th style="text-align: right;">       C64</th><th style="text-align: right;">       C65</th><th style="text-align: right;">        C66</th><th style="text-align: right;">       C67</th><th style="text-align: right;">      C68</th><th style="text-align: right;">      C69</th><th style="text-align: right;"> ...

# %%
ext_train_new = ext_reviews_new[ext_reviews_new["Train"] == "Yes"]
ext_test_new = ext_reviews_new[ext_reviews_new["Train"] == "No"]

# %%
ext_test_simple = ext_test_new.drop([2, 6, 9])

# %%
predictors = ['ProductId', 'UserId', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Time'] + summary_vecs.names + review_vecs.names 
response = 'PositiveReview'

# %% [markdown]
# ## 1.6 Leaderboard

# %%
run_time=1500

# %%
# Set up AutoML
aml = H2OAutoML()

# %%
aml.train(x=predictors,y=response,training_frame=ext_train_new)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
print(aml.leaderboard)
# Out:
# <table>
# <thead>
# <tr><th>model_id                        </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoost_1_AutoML_20190426_155539</td><td style="text-align: right;">0.896382</td><td style="text-align: right;"> 0.379217</td><td style="text-align: right;">              0.204441</td><td style="text-align: right;">0.343743</td><td style="text-align: right;">0.118159</td></tr>
# </tbody>
# </table>

# %% [markdown]
# # 2 Training Models

# %% [markdown]
# ## 2.1 Generalized Linear Model

# %% [markdown]
# ### 2.1.1 Train & Fit Model

# %%
# Initialize
local_glm_plus = H2OGeneralizedLinearEstimator(family='binomial', model_id='glm_surrogate', lambda_search=True)
# train 
local_glm_plus.train(x=predictors, y=response, training_frame=ext_train_new)
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %% [markdown]
# ### 2.1.2 Interpretability

# %% [markdown]
# #### Variable Importance

# %%
local_glm_plus.varimp_plot()

# %% [markdown]
# #### Partial Dependence Plot (PDP)

# %%
pdp_local_linear_plus = local_glm_plus.partial_plot(data = ext_train_new, cols = ["HelpfulnessNumerator"])
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %% [markdown]
# #### Individual Conditional Expectation (ICE)

# %%
HelpfulnessNumerator_ice_df = ice(data=ext_test_simple, column='HelpfulnessNumerator', model=local_glm_plus)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# glm prediction progress: |████████████████████████████████████████████████| 100%

# %%
ice_plot(HelpfulnessNumerator_ice_df, linewidth=0.5, color_by='Score', cmap='coolwarm',
        plot_pdp=True, pdp_kwargs={'c': 'k', 'linewidth': 3})
vals = HelpfulnessNumerator_ice_df.columns.get_level_values('Score').values
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vals.min(), vmax=vals.max()))
sm._A = []
plt.colorbar(sm, label='Score')
plt.ylabel('Pred. AV %ile')
plt.xlabel('HelpfulnessNumerator');

# %% [markdown]
# ### 2.1.3 Matrix

# %%
print('\nLocal GLM Coefficients:')
for c_name, c_val in sorted(local_glm_plus.coef().items(), key=operator.itemgetter(1)):
    if c_val != 0.0:
        print('%s %s' % (str(c_name + ':').ljust(25), c_val))

# %%
local_glm_plus.r2(train=True, valid=True)

# %%
local_glm_plus.auc()

# %%
local_glm_plus.confusion_matrix()

# %% [markdown]
# ## 2.2 Logistic Regression

# %% [markdown]
# ### 2.2.1 Train & Fit Model

# %%
glm_logistic_plus_summary = H2OGeneralizedLinearEstimator(family = "binomial")
glm_logistic_plus_summary.train(x=predictors, 
                               y= response, 
                               training_frame = ext_train_new, 
                               validation_frame = ext_test_new, 
                               model_id="glm_logistic")

# %% [markdown]
# ### 2.2.2 Interpretability

# %% [markdown]
# #### Variable Importance

# %%
glm_logistic_plus_summary.varimp_plot()

# %% [markdown]
# #### Partial Dependence Plot (PDP)

# %%
pdp_word_vecs = glm_logistic_plus_summary.partial_plot(data = ext_train_new, cols = ["C29"])
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %% [markdown]
# #### Individual Conditional Expectation (ICE)

# %%
ext_test_simple_lice = ext_test_simple.sort('C29')

# %%
ext_test_simple_lices = h2o.H2OFrame(ext_test_simple_lice.as_data_frame().iloc[::25])
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
ext_test_simple_lices.shape
# Out:
# (447, 209)

# %%
C29_ice_df = ice(data=ext_test_simple_lices, column='C29', model=glm_logistic_plus_summary)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# glm prediction progress: |████████████████████████████████████████████████| 100%

# %%
ice_plot(C29_ice_df, linewidth=0.5, color_by='Score', cmap='coolwarm',
        plot_pdp=True, pdp_kwargs={'c': 'k', 'linewidth': 3})
vals = C29_ice_df.columns.get_level_values('Score').values
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vals.min(), vmax=vals.max()))
sm._A = []
plt.colorbar(sm, label='Score')
plt.ylabel('Pred. AV %ile')
plt.xlabel('C29');

# %% [markdown]
# ### 2.2.3 Matrix

# %%
print("With Summary and Review Embeddings AUC: " + str(round(glm_logistic_plus_summary.auc(valid = True), 3)))
# Out:
# With Summary and Review Embeddings AUC: 0.854

# %%
glm_logistic_plus_summary.confusion_matrix(valid = True)
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4744080370497271:
#        0     1     Error    Rate
# -----  ----  ----  -------  ----------------
# 0      2454  1758  0.4174   (1758.0/4212.0)
# 1      572   6368  0.0824   (572.0/6940.0)
# Total  3026  8126  0.2089   (2330.0/11152.0)

# %%
glm_logistic_plus_summary.confusion_matrix(valid = True)
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4744080370497271:
#        0     1     Error    Rate
# -----  ----  ----  -------  ----------------
# 0      2454  1758  0.4174   (1758.0/4212.0)
# 1      572   6368  0.0824   (572.0/6940.0)
# Total  3026  8126  0.2089   (2330.0/11152.0)

# %% [markdown]
# ## 2.3 Decision Tree

# %% [markdown]
# ### 2.3.1 Train & Fit Model

# %%
# initialize single tree surrogate model
model_id = 'dt_surrogate_mojo'

# train single tree surrogate model
surrogate = H2OGradientBoostingEstimator(ntrees=1,
                                         sample_rate=1,
                                         col_sample_rate=1,
                                         max_depth=3,
                                         seed=12345,
                                         model_id=model_id)

_ = surrogate.train(x=predictors, y=response, training_frame=ext_train_new)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
# persist MOJO (compiled, representation of trained model)
# from which to generate plot of surrogate
mojo_path = surrogate.download_mojo(path='data')

print(surrogate)
print('Generated MOJO path:\n', mojo_path)
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  dt_surrogate_mojo
#
#
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.22484148909893112
# RMSE: 0.47417453442686175
# LogLoss: 0.641473474981203
# Mean Per-Class Error: 0.35673493790920763
# AUC: 0.6864312338888747
# pr_auc: 0.49617961954787737
# Gini: 0.37286246777774945
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.6237288109631749:
#        0     1      Error    Rate
# -----  ----  -----  -------  -----------------
# 0      2513  13381  0.8419   (13381.0/15894.0)
# 1      928   27580  0.0326   (928.0/28508.0)
# Total  3441  40961  0.3223   (14309.0/44402.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.623729     0.794023  6
# max f2                       0.604016     0.899681  7
# max f0point5                 0.645697     0.748373  3
# max accuracy                 0.628838     0.68891   4
# max precision                0.659529     0.818903  0
# max recall                   0.604016     1         7
# max specificity              0.659529     0.866428  0
# max absolute_mcc             0.645697     0.299128  3
# max min_per_class_accuracy   0.646897     0.606251  1
# max mean_per_class_accuracy  0.645697     0.643265  3
# Gains/Lift Table: Avg response rate: 64.20 %, avg score: 64.19 %
#     group    cumulative_data_fraction    lower_threshold    lift      cumulative_lift    response_rate    score     cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  --------  -----------------  ---------------  --------  --------------------------  ------------------  --------------  -------------------------  --------  -----------------
#     1        0.26402                     0.659529           1.27546   1.27546            0.818903         0.659529  0.818903                    0.659529            0.336748        0.336748                   27.5464   27.5464
#     2        0.514526                    0.646897           1.07583   1.17827            0.690731         0.646897  0.7565                      0.653379            0.269503        0.606251                   7.58325   17.827
#     3        0.697806                    0.645697           1.05915   1.14698            0.68002          0.645832  0.736412                    0.651397            0.194121        0.800372                   5.91495   14.6983
#     4        0.743773                    0.628838           0.795934  1.12529            0.511024         0.628838  0.722483                    0.650003            0.0365862       0.836958                   -20.4066  12.5287
#     5        0.808297                    0.625959           0.751854  1.09548            0.482723         0.625959  0.703344                    0.648083            0.0485127       0.885471                   -24.8146  9.54771
#     6        0.922503                    0.623729           0.717796  1.04872            0.460856         0.623729  0.673323                    0.645068            0.081977        0.967448                   -28.2204  4.87199
#     7        1                           0.604016           0.420048  1                  0.269689         0.604016  0.642043                    0.641887            0.0325523       1                          -57.9952  0
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_logloss    training_auc    training_pr_auc    training_lift    training_classification_error
# --  -------------------  ----------  -----------------  ---------------  ------------------  --------------  -----------------  ---------------  -------------------------------
#     2019-04-24 14:06:22  0.003 sec   0                  0.479399         0.652234            0.5             0                  1                0.357957
#     2019-04-24 14:06:22  0.116 sec   1                  0.474175         0.641473            0.686431        0.49618            1.27546          0.32226
# Variable Importances:
# variable      relative_importance    scaled_importance    percentage
# ------------  ---------------------  -------------------  -------------------
# summary_C42   405.02166748046875     1.0                  0.35032449823729933
# C26           249.81227111816406     0.6167874244165238   0.2160757449777949
# summary_C54   248.7382354736328      0.6141356264245483   0.2151467551768294
# summary_C97   116.34648895263672     0.28725991297304426  0.100634184875972
# C22           74.61551666259766      0.18422598752990374  0.06453887664368449
# ---           ---                    ---                  ---
# summary_C95   0.0                    0.0                  0.0
# summary_C96   0.0                    0.0                  0.0
# summary_C98   0.0                    0.0                  0.0
# summary_C99   0.0                    0.0                  0.0
# summary_C100  0.0                    0.0                  0.0
# See the whole table with table.as_data_frame()
#
# Generated MOJO path:
#  /Users/mandy/Documents/Study/AI-Addin/data/dt_surrogate_mojo.zip

# %%
details = False # print more info on tree, details = True
title = 'Amazon Reviews Decision Tree Surrogate'

hs = H2OLocalServer()
h2o_jar_path = hs._find_jar()
print('Discovered H2O jar path:\n', h2o_jar_path)

gv_file_name = model_id + '.gv'
gv_args = str('-cp ' + h2o_jar_path +
              ' hex.genmodel.tools.PrintMojo --tree 0 -i '
              + mojo_path + ' -o ').split()
gv_args.insert(0, 'java')
gv_args.append(gv_file_name)

if details:
    gv_args.append('--detail')

if title is not None:
    gv_args = gv_args + ['--title', title]
    
print()
print('Calling external process ...')
print(' '.join(gv_args))
    
_ = subprocess.call(gv_args)
# Out:
# Discovered H2O jar path:
#  /anaconda3/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar
#
# Calling external process ...
# java -cp /anaconda3/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar hex.genmodel.tools.PrintMojo --tree 0 -i /Users/mandy/Documents/Study/AI-Addin/data/dt_surrogate_mojo.zip -o dt_surrogate_mojo.gv --title Amazon Reviews Decision Tree Surrogate

# %%
png_file_name = model_id + '.png'
png_args = str('dot -Tpng ' + gv_file_name + ' -o ' + png_file_name)
png_args = png_args.split()

print('Calling external process ...')
print(' '.join(png_args))

_ = subprocess.call(png_args)
# Out:
# Calling external process ...
# dot -Tpng dt_surrogate_mojo.gv -o dt_surrogate_mojo.png

# %%
display(Image((png_file_name)))

# %% [markdown]
# ### 2.3.2 Interpretability

# %% [markdown]
# #### Variable Importance

# %%
surrogate.varimp_plot()

# %% [markdown]
# #### Partial Dependence Plot (PDP)

# %%
pdp_word_vecs = surrogate.partial_plot(data = ext_train_new, cols = ["C26"])
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %% [markdown]
# #### Individual Conditional Expectation (ICE)

# %%
ext_test_simple_dice = ext_test_simple.sort('C26')

# %%
ext_test_simple_dices = h2o.H2OFrame(ext_test_simple_dice.as_data_frame().iloc[::20])
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
ext_test_simple_dices.shape
# Out:
# (558, 209)

# %%
C26_ice_df = ice(data=ext_test_simple_dices, column='C26', model=surrogate)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%

# %%
ice_plot(C26_ice_df, linewidth=0.5, color_by='Score', cmap='coolwarm',
        plot_pdp=True, pdp_kwargs={'c': 'k', 'linewidth': 3})
vals = C26_ice_df.columns.get_level_values('Score').values
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vals.min(), vmax=vals.max()))
sm._A = []
plt.colorbar(sm, label='Score')
plt.ylabel('Pred. AV %ile')
plt.xlabel('C26');

# %% [markdown]
# ### 2.3.3 Matrix

# %%
print(surrogate)
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  dt_surrogate_mojo
#
#
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.22490468188680712
# RMSE: 0.4742411642685682
# LogLoss: 0.6415846447228967
# Mean Per-Class Error: 0.35615213187394557
# AUC: 0.692578222817862
# pr_auc: 0.42284625175470336
# Gini: 0.38515644563572393
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.6287949244602625:
#        0     1      Error    Rate
# -----  ----  -----  -------  -----------------
# 0      4338  11556  0.7271   (11556.0/15894.0)
# 1      2322  26186  0.0815   (2322.0/28508.0)
# Total  6660  37742  0.3126   (13878.0/44402.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.628795     0.790521  5
# max f2                       0.61158      0.899681  7
# max f0point5                 0.641948     0.745161  3
# max accuracy                 0.628795     0.687447  5
# max precision                0.65891      0.812562  0
# max recall                   0.61158      1         7
# max specificity              0.65891      0.821253  0
# max absolute_mcc             0.641948     0.288001  3
# max min_per_class_accuracy   0.644602     0.628162  2
# max mean_per_class_accuracy  0.644602     0.643848  2
# Gains/Lift Table: Avg response rate: 64.20 %, avg score: 64.19 %
#     group    cumulative_data_fraction    lower_threshold    lift      cumulative_lift    response_rate    score     cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  --------  -----------------  ---------------  --------  --------------------------  ------------------  --------------  -------------------------  --------  -----------------
#     1        0.341358                    0.65891            1.26559   1.26559            0.812562         0.65891   0.812562                    0.65891             0.432019        0.432019                   26.5588   26.5588
#     2        0.556552                    0.644602           1.05726   1.18504            0.678807         0.645708  0.760845                    0.653805            0.227515        0.659534                   5.72606   18.5037
#     3        0.645782                    0.641948           0.998516  1.15926            0.64109          0.641948  0.744298                    0.652167            0.0890978       0.748632                   -0.1484   15.9265
#     4        0.746971                    0.633616           0.869415  1.12               0.558202         0.633616  0.719088                    0.649654            0.0879753       0.836607                   -13.0585  12
#     5        0.850007                    0.628795           0.795275  1.08064            0.510601         0.628795  0.693816                    0.647125            0.0819419       0.918549                   -20.4725  8.06375
#     6        1                           0.61158            0.54303   1                  0.348649         0.612202  0.642043                    0.641887            0.0814508       1                          -45.697   0
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_logloss    training_auc    training_pr_auc    training_lift    training_classification_error
# --  -------------------  ----------  -----------------  ---------------  ------------------  --------------  -----------------  ---------------  -------------------------------
#     2019-04-23 19:11:28  0.005 sec   0                  0.479399         0.652234            0.5             0                  1                0.357957
#     2019-04-23 19:11:28  0.107 sec   1                  0.474241         0.641585            0.692578        0.422846           1.26559          0.312553
# Variable Importances:
# variable      relative_importance    scaled_importance    percentage
# ------------  ---------------------  -------------------  -------------------
# summary_C24   420.74456787109375     1.0                  0.3677554104048984
# summary_C78   290.751953125          0.691041490080698    0.25413424679143964
# summary_C25   200.93856811523438     0.4775785202217922   0.17563208470472927
# C48           118.46067810058594     0.28155010699241995  0.10354157514654046
# C46           61.119380950927734     0.14526481294858518  0.05342192090329775
# ---           ---                    ---                  ---
# summary_C96   0.0                    0.0                  0.0
# summary_C97   0.0                    0.0                  0.0
# summary_C98   0.0                    0.0                  0.0
# summary_C99   0.0                    0.0                  0.0
# summary_C100  0.0                    0.0                  0.0
# See the whole table with table.as_data_frame()

# %% [markdown]
# ## 2.4 Gradient Boosting

# %% [markdown]
# ### 2.4.1 Train & Fit Model

# %%
gbm = H2OGradientBoostingEstimator(stopping_metric = "AUC",
                                           stopping_tolerance = 0.001,
                                           stopping_rounds = 5, 
                                           score_tree_interval = 10, 
                                           model_id = 'gbm.hex')
gbm.train(x = predictors, 
                   y = response,
                  training_frame = ext_train_new,
                  validation_frame = ext_test_new)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %% [markdown]
# ### 2.4.2 Interpretability

# %% [markdown]
# #### Variable Importance

# %%
gbm.varimp_plot()

# %% [markdown]
# #### Partial Dependence Plot (PDP)

# %%
pdp_helpfulness = gbm.partial_plot(ext_train_new, cols = ['C45'])
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %% [markdown]
# #### Individual Conditional Expectation (ICE)

# %%
ext_test_simple_gice = ext_test_simple.sort('C45')

# %%
ext_test_simple_gices = h2o.H2OFrame(ext_test_simple_gice.as_data_frame().iloc[::15])
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
ext_test_simple_gices.shape
# Out:
# (558, 209)

# %%
C45_ice_df = ice(data=ext_test_simple_gices, column='C45', model=gbm)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%

# %%
ice_plot(C45_ice_df, linewidth=0.5, color_by='Score', cmap='coolwarm',
        plot_pdp=True, pdp_kwargs={'c': 'k', 'linewidth': 3})
vals = C45_ice_df.columns.get_level_values('Score').values
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmin=vals.min(), vmax=vals.max()))
sm._A = []
plt.colorbar(sm, label='Score')
plt.ylabel('Pred. AV %ile')
plt.xlabel('C45');

# %% [markdown]
# ### 2.4.3 Matrix

# %%
print("AUC on validation data: " + str(round(gbm.auc(valid = True), 3)))
# Out:
# AUC on validation data: 0.847

# %%
gbm.confusion_matrix(valid=True)
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4600680081556039:
#        0     1     Error    Rate
# -----  ----  ----  -------  ----------------
# 0      2329  1883  0.4471   (1883.0/4212.0)
# 1      510   6430  0.0735   (510.0/6940.0)
# Total  2839  8313  0.2146   (2393.0/11152.0)

# %%
gbm.r2(train=True, valid=True)
# Out:
# {'train': 0.4450081600704048, 'valid': 0.35888062454985814}

# %%
 h2o.cluster().shutdown()
# Out:
# H2O session _sid_9208 closed.
